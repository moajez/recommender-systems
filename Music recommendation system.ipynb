# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from sklearn.feature_extraction.text import CountVectorized
from collections import Counter
from wordcloud import WordCloud
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from surprise import Reader, Dataset, SVD
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 import matplotlib.pyplot as plt
#       4 import plotly.express as px
#       5 from sklearn.feature_extraction.text import CountVectorizer
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
df=pd.read_csv("/content/ex.csv")
df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba      8.8/10
# 1     BollywoodDanceRomantic                Luka Chuppi      9.0/10
# 2             BollywoodDance                  Gully Boy      9.7/10
# 3             BollywoodDance              Total Dhamaal      9.1/10
# 4          BollywoodRomantic                     Simmba      9.2/10
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural      6.2/10
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai      7.2/10
# 2417          BollywoodDance                      Lamhe      7.5/10
# 2418          BollywoodDance          Shola Aur Shabnam      6.5/10
# 2419          BollywoodDance          Shola Aur Shabnam      6.6/10
#
# [2420 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Song-Name          0
# Singer/Artists    10
# Genre              0
# Album/Movie        3
# User-Rating        0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Song-Name         0
# Singer/Artists    0
# Genre             0
# Album/Movie       0
# User-Rating       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 16

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (2391, 5)

# %%
df.head()
# Out:
#           Song-Name                                    Singer/Artists  \
# 0       Aankh Marey               Kumar Sanu, Mika Singh, Neha Kakkar
# 1         Coca Cola                          Neha Kakkar, Tony Kakkar
# 2  Apna Time Aayega                                     Ranveer Singh
# 3            Mungda             Jyotica Tangri, Shaan, Subhro Ganguly
# 4          Tere Bin  Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
#
#                     Genre    Album/Movie User-Rating
# 0          BollywoodDance         Simmba      8.8/10
# 1  BollywoodDanceRomantic    Luka Chuppi      9.0/10
# 2          BollywoodDance      Gully Boy      9.7/10
# 3          BollywoodDance  Total Dhamaal      9.1/10
# 4       BollywoodRomantic         Simmba      9.2/10

# %%
df['User-Rating']
# Out:
# 0       8.8/10
# 1       9.0/10
# 2       9.7/10
# 3       9.1/10
# 4       9.2/10
#          ...
# 2415    6.2/10
# 2416    7.2/10
# 2417    7.5/10
# 2418    6.5/10
# 2419    6.6/10
# Name: User-Rating, Length: 2391, dtype: object

# %%
l=[]
for i in df['User-Rating']:
    l.append(i[:3])
l
# Out:
# ['8.8',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.5',
#  '9.2',
#  '9.6',
#  '8.8',
#  '8.4',
#  '9.1',
#  '9.2',
#  '9.0',
#  '9.7',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.5',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.2',
#  '9.5',
#  '9.4',
#  '8.7',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.0',
#  '9.0',
#  '9.1',
#  '8.4',
#  '8.4',
#  '8.8',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.6',
#  '9.0',
#  '9.1',
#  '8.5',
#  '9.5',
#  '8.5',
#  '9.7',
#  '8.9',
#  '9.6',
#  '8.5',
#  '9.1',
#  '8.7',
#  '8.6',
#  '9.3',
#  '9.7',
#  '8.9',
#  '9.0',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.0',
#  '9.7',
#  '9.2',
#  '9.1',
#  '9.0',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.7',
#  '9.0',
#  '8.1',
#  '8.1',
#  '9.5',
#  '9.1',
#  '8.6',
#  '9.4',
#  '9.0',
#  '9.0',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.6',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.6',
#  '9.3',
#  '7.7',
#  '9.2',
#  '9.3',
#  '7.7',
#  '9.0',
#  '9.5',
#  '9.4',
#  '9.0',
#  '9.2',
#  '9.0',
#  '9.4',
#  '9.4',
#  '9.1',
#  '9.3',
#  '9.2',
#  '9.1',
#  '9.0',
#  '9.8',
#  '8.9',
#  '6.8',
#  '8.9',
#  '8.2',
#  '8.7',
#  '8.2',
#  '9.4',
#  '9.0',
#  '8.9',
#  '9.9',
#  '8.7',
#  '8.9',
#  '9.6',
#  '9.5',
#  '8.7',
#  '8.4',
#  '9.5',
#  '9.3',
#  '8.3',
#  '9.2',
#  '9.3',
#  '8.9',
#  '8.7',
#  '9.1',
#  '9.6',
#  '9.4',
#  '9.6',
#  '8.6',
#  '9.1',
#  '9.2',
#  '9.6',
#  '9.6',
#  '8.8',
#  '8.7',
#  '9.4',
#  '9.0',
#  '8.1',
#  '9.6',
#  '9.3',
#  '9.4',
#  '9.2',
#  '9.5',
#  '9.6',
#  '9.9',
#  '9.4',
#  '9.7',
#  '9.4',
#  '9.4',
#  '9.5',
#  '9.3',
#  '8.1',
#  '8.5',
#  '9.4',
#  '8.6',
#  '9.4',
#  '9.3',
#  '9.1',
#  '9.2',
#  '9.0',
#  '7.2',
#  '9.7',
#  '8.5',
#  '7.7',
#  '9.3',
#  '9.3',
#  '9.7',
#  '9.0',
#  '9.2',
#  '9.2',
#  '8.8',
#  '9.1',
#  '9.3',
#  '9.2',
#  '9.0',
#  '9.2',
#  '8.5',
#  '9.6',
#  '9.3',
#  '9.7',
#  '8.5',
#  '8.9',
#  '9.6',
#  '8.7',
#  '8.4',
#  '9.2',
#  '9.2',
#  '9.1',
#  '9.1',
#  '8.7',
#  '8.9',
#  '9.4',
#  '8.4',
#  '9.0',
#  '9.1',
#  '9.4',
#  '9.6',
#  '9.3',
#  '9.5',
#  '9.5',
#  '9.2',
#  '7.6',
#  '8.9',
#  '9.6',
#  '9.4',
#  '9.4',
#  '8.6',
#  '9.6',
#  '8.9',
#  '8.6',
#  '9.2',
#  '8.7',
#  '8.9',
#  '8.7',
#  '9.6',
#  '9.2',
#  '9.2',
#  '9.2',
#  '9.4',
#  '9.0',
#  '9.4',
#  '9.7',
#  '8.8',
#  '9.6',
#  '9.4',
#  '8.9',
#  '9.4',
#  '9.0',
#  '9.5',
#  '9.5',
#  '9.3',
#  '9.7',
#  '9.0',
#  '8.2',
#  '9.4',
#  '9.1',
#  '8.8',
#  '9.1',
#  '9.2',
#  '9.2',
#  '9.4',
#  '9.0',
#  '9.7',
#  '9.4',
#  '9.1',
#  '8.8',
#  '9.1',
#  '9.1',
#  '8.7',
#  '9.7',
#  '9.4',
#  '9.5',
#  '8.8',
#  '8.9',
#  '9.3',
#  '8.5',
#  '9.3',
#  '9.2',
#  '9.5',
#  '8.9',
#  '9.1',
#  '9.3',
#  '9.4',
#  '9.3',
#  '9.6',
#  '8.8',
#  '9.6',
#  '9.1',
#  '8.8',
#  '8.8',
#  '9.4',
#  '9.4',
#  '9.4',
#  '8.1',
#  '9.0',
#  '8.5',
#  '7.5',
#  '9.3',
#  '9.5',
#  '7.9',
#  '9.0',
#  '9.6',
#  '9.4',
#  '9.5',
#  '9.0',
#  '9.5',
#  '9.5',
#  '8.8',
#  '9.4',
#  '7.3',
#  '9.4',
#  '9.1',
#  '9.6',
#  '9.7',
#  '8.8',
#  '9.1',
#  '9.1',
#  '9.1',
#  '9.0',
#  '9.3',
#  '8.7',
#  '8.2',
#  '9.3',
#  '9.3',
#  '8.4',
#  '9.0',
#  '9.3',
#  '8.9',
#  '9.0',
#  '9.4',
#  '9.1',
#  '9.4',
#  '9.3',
#  '9.6',
#  '9.1',
#  '9.0',
#  '8.9',
#  '8.5',
#  '9.2',
#  '8.2',
#  '9.2',
#  '9.4',
#  '9.3',
#  '9.4',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.3',
#  '9.2',
#  '9.2',
#  '9.6',
#  '9.4',
#  '9.3',
#  '9.1',
#  '9.3',
#  '9.6',
#  '9.1',
#  '8.8',
#  '8.8',
#  '9.1',
#  '9.3',
#  '9.5',
#  '9.3',
#  '8.8',
#  '8.8',
#  '9.2',
#  '8.7',
#  '9.4',
#  '9.3',
#  '9.1',
#  '9.7',
#  '8.6',
#  '9.1',
#  '8.9',
#  '9.0',
#  '9.2',
#  '9.1',
#  '9.1',
#  '9.1',
#  '9.1',
#  '9.1',
#  '9.1',
#  '8.8',
#  '8.8',
#  '9.4',
#  '7.7',
#  '8.4',
#  '7.4',
#  '9.3',
#  '9.1',
#  '8.7',
#  '8.9',
#  '9.3',
#  '9.4',
#  '9.6',
#  '9.4',
#  '8.7',
#  '9.0',
#  '9.1',
#  '9.1',
#  '9.1',
#  '9.4',
#  '9.4',
#  '9.5',
#  '9.2',
#  '9.3',
#  '8.9',
#  '8.4',
#  '9.0',
#  '8.5',
#  '8.7',
#  '9.2',
#  '8.7',
#  '9.0',
#  '9.4',
#  '9.2',
#  '9.5',
#  '8.7',
#  '9.2',
#  '8.4',
#  '8.9',
#  '8.2',
#  '8.9',
#  '8.6',
#  '9.6',
#  '9.7',
#  '9.4',
#  '8.3',
#  '9.5',
#  '9.3',
#  '9.2',
#  '8.8',
#  '7.9',
#  '9.3',
#  '8.9',
#  '9.4',
#  '9.4',
#  '8.2',
#  '9.2',
#  '9.0',
#  '9.3',
#  '8.9',
#  '9.6',
#  '9.2',
#  '7.9',
#  '8.6',
#  '9.2',
#  '9.2',
#  '8.5',
#  '9.3',
#  '9.6',
#  '9.6',
#  '9.4',
#  '9.1',
#  '9.2',
#  '8.8',
#  '9.1',
#  '8.2',
#  '9.4',
#  '8.6',
#  '9.2',
#  '9.5',
#  '8.4',
#  '9.3',
#  '7.9',
#  '9.2',
#  '9.1',
#  '9.2',
#  '9.1',
#  '9.5',
#  '9.4',
#  '8.8',
#  '8.3',
#  '8.4',
#  '9.0',
#  '9.7',
#  '8.7',
#  '9.5',
#  '9.3',
#  '9.3',
#  '9.2',
#  '8.5',
#  '9.3',
#  '9.3',
#  '9.2',
#  '9.2',
#  '9.2',
#  '7.8',
#  '8.8',
#  '9.4',
#  '8.7',
#  '9.0',
#  '9.4',
#  '8.7',
#  '8.4',
#  '8.7',
#  '9.5',
#  '9.7',
#  '9.3',
#  '9.0',
#  '8.0',
#  '9.2',
#  '8.6',
#  '9.6',
#  '9.1',
#  '9.3',
#  '7.9',
#  '8.7',
#  '9.3',
#  '9.0',
#  '8.8',
#  '9.0',
#  '9.3',
#  '9.3',
#  '9.3',
#  '9.2',
#  '9.2',
#  '9.0',
#  '8.4',
#  '8.9',
#  '9.0',
#  '9.1',
#  '8.1',
#  '8.9',
#  '9.4',
#  '8.7',
#  '8.5',
#  '9.2',
#  '9.4',
#  '9.4',
#  '8.1',
#  '9.2',
#  '9.5',
#  '8.8',
#  '8.7',
#  '9.0',
#  '9.2',
#  '9.7',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.4',
#  '9.6',
#  '8.8',
#  '9.0',
#  '9.1',
#  '9.3',
#  '8.6',
#  '9.0',
#  '8.9',
#  '9.4',
#  '9.5',
#  '8.9',
#  '8.9',
#  '9.1',
#  '7.9',
#  '9.8',
#  '9.4',
#  '9.2',
#  '9.4',
#  '8.9',
#  '8.6',
#  '9.1',
#  '9.4',
#  '9.5',
#  '9.2',
#  '8.7',
#  '8.5',
#  '9.2',
#  '9.7',
#  '9.4',
#  '9.3',
#  '9.5',
#  '9.4',
#  '9.1',
#  '9.6',
#  '9.5',
#  '9.4',
#  '9.1',
#  '9.2',
#  '9.6',
#  '8.7',
#  '7.9',
#  '8.7',
#  '8.7',
#  '8.1',
#  '8.2',
#  '8.9',
#  '8.9',
#  '9.6',
#  '9.0',
#  '9.3',
#  '9.6',
#  '9.3',
#  '9.3',
#  '9.3',
#  '9.5',
#  '8.9',
#  '8.8',
#  '8.8',
#  '9.6',
#  '9.2',
#  '9.7',
#  '8.6',
#  '8.7',
#  '9.2',
#  '9.2',
#  '9.2',
#  '9.3',
#  '9.3',
#  '9.5',
#  '9.5',
#  '8.9',
#  '9.1',
#  '8.7',
#  '9.6',
#  '9.3',
#  '9.6',
#  '8.7',
#  '8.7',
#  '8.9',
#  '9.2',
#  '9.5',
#  '9.3',
#  '9.3',
#  '9.4',
#  '9.3',
#  '8.9',
#  '9.2',
#  '9.5',
#  '7.6',
#  '9.6',
#  '9.7',
#  '8.0',
#  '9.4',
#  '9.5',
#  '9.2',
#  '9.3',
#  '8.8',
#  '9.4',
#  '9.5',
#  '9.5',
#  '9.1',
#  '9.7',
#  '9.4',
#  '9.1',
#  '8.9',
#  '9.3',
#  '9.1',
#  '9.4',
#  '9.5',
#  '9.1',
#  '9.6',
#  '9.0',
#  '8.5',
#  '9.2',
#  '9.3',
#  '9.0',
#  '9.6',
#  '9.5',
#  '9.4',
#  '9.3',
#  '9.2',
#  '9.3',
#  '9.5',
#  '8.1',
#  '9.2',
#  '9.4',
#  '9.5',
#  '9.4',
#  '8.6',
#  '9.6',
#  '9.2',
#  '9.2',
#  '9.2',
#  '9.2',
#  '8.9',
#  '9.6',
#  '9.3',
#  '9.0',
#  '9.6',
#  '9.0',
#  '9.2',
#  '9.3',
#  '9.4',
#  '8.7',
#  '9.6',
#  '9.3',
#  '8.9',
#  '9.3',
#  '9.5',
#  '9.5',
#  '9.0',
#  '9.5',
#  '9.2',
#  '8.8',
#  '9.6',
#  '8.7',
#  '8.3',
#  '9.3',
#  '8.4',
#  '9.1',
#  '8.3',
#  '9.6',
#  '9.6',
#  '8.9',
#  '9.5',
#  '9.5',
#  '8.8',
#  '9.0',
#  '9.6',
#  '9.6',
#  '9.6',
#  '8.7',
#  '8.5',
#  '9.5',
#  '9.6',
#  '8.2',
#  '9.1',
#  '9.3',
#  '8.6',
#  '9.3',
#  '9.5',
#  '9.1',
#  '9.2',
#  '9.6',
#  '9.6',
#  '8.8',
#  '8.8',
#  '9.1',
#  '9.0',
#  '9.3',
#  '9.1',
#  '9.7',
#  '9.0',
#  '9.1',
#  '9.2',
#  '9.6',
#  '9.4',
#  '9.0',
#  '9.7',
#  '9.4',
#  '9.3',
#  '9.2',
#  '9.1',
#  '8.9',
#  '9.3',
#  '9.7',
#  '9.4',
#  '8.9',
#  '9.3',
#  '8.8',
#  '9.0',
#  '9.1',
#  '9.3',
#  '9.2',
#  '9.5',
#  '8.8',
#  '9.7',
#  '9.4',
#  '9.2',
#  '9.0',
#  '8.9',
#  '8.6',
#  '9.1',
#  '9.0',
#  '9.6',
#  '9.4',
#  '9.3',
#  '9.5',
#  '9.6',
#  '9.1',
#  '7.3',
#  '9.5',
#  '8.2',
#  '9.0',
#  '8.4',
#  '9.4',
#  '9.5',
#  '8.5',
#  '9.5',
#  '8.8',
#  '9.3',
#  '9.5',
#  '8.1',
#  '8.7',
#  '9.1',
#  '9.2',
#  '9.3',
#  '9.3',
#  '8.7',
#  '9.5',
#  '9.6',
#  '9.1',
#  '9.0',
#  '9.3',
#  '9.1',
#  '8.2',
#  '8.6',
#  '9.5',
#  '9.4',
#  '9.3',
#  '8.9',
#  '8.9',
#  '9.3',
#  '9.1',
#  '7.9',
#  '9.7',
#  '8.8',
#  '9.1',
#  '9.1',
#  '9.4',
#  '9.4',
#  '9.7',
#  '9.1',
#  '8.4',
#  '9.3',
#  '9.2',
#  '9.6',
#  '9.2',
#  '9.3',
#  '9.1',
#  '8.9',
#  '9.0',
#  '9.2',
#  '8.8',
#  '9.2',
#  '9.4',
#  '9.4',
#  '9.4',
#  '8.2',
#  '9.3',
#  '9.3',
#  '9.1',
#  '9.4',
#  '9.3',
#  '9.4',
#  '8.8',
#  '9.0',
#  '7.6',
#  '9.3',
#  '8.3',
#  '9.4',
#  '8.9',
#  '9.4',
#  '9.3',
#  '9.3',
#  '9.7',
#  '9.5',
#  '9.6',
#  '9.4',
#  '9.2',
#  '9.3',
#  '9.5',
#  '9.3',
#  '9.5',
#  '9.3',
#  '9.3',
#  '9.2',
#  '8.2',
#  '8.5',
#  '9.7',
#  '9.6',
#  '9.2',
#  '9.3',
#  '8.3',
#  '8.6',
#  '9.0',
#  '9.6',
#  '8.7',
#  '9.1',
#  '9.1',
#  '9.6',
#  '9.5',
#  '9.4',
#  '9.2',
#  '8.8',
#  '9.5',
#  '9.4',
#  '9.0',
#  '9.1',
#  '9.4',
#  '9.2',
#  '9.4',
#  '7.8',
#  '9.5',
#  '9.1',
#  '7.4',
#  '9.2',
#  '9.0',
#  '9.3',
#  '8.6',
#  '8.9',
#  '9.5',
#  '9.5',
#  '9.6',
#  '9.1',
#  '9.1',
#  '7.7',
#  '7.7',
#  '9.7',
#  '8.3',
#  '9.1',
#  '9.2',
#  '9.4',
#  '9.3',
#  '9.0',
#  '9.2',
#  '9.6',
#  '7.7',
#  '8.6',
#  '9.6',
#  '9.4',
#  '9.3',
#  '8.8',
#  '9.0',
#  '9.1',
#  '9.0',
#  '8.2',
#  '8.8',
#  '9.5',
#  '8.8',
#  '9.4',
#  '9.4',
#  '9.3',
#  '9.2',
#  '9.2',
#  '9.2',
#  '9.4',
#  '9.4',
#  '9.6',
#  '8.6',
#  '9.6',
#  '9.2',
#  '8.5',
#  '8.4',
#  '9.3',
#  '7.5',
#  '9.4',
#  '9.5',
#  '9.3',
#  '8.2',
#  '8.9',
#  '9.4',
#  '9.0',
#  '9.3',
#  '8.8',
#  '8.3',
#  '8.6',
#  '9.0',
#  '9.0',
#  '8.4',
#  '9.6',
#  '8.4',
#  '9.5',
#  '8.8',
#  '9.4',
#  '9.3',
#  '9.4',
#  '9.2',
#  '8.9',
#  '9.2',
#  '9.4',
#  '9.6',
#  '9.3',
#  '9.6',
#  '8.2',
#  '9.1',
#  '8.2',
#  '8.5',
#  '9.3',
#  '8.5',
#  '9.2',
#  '9.4',
#  '9.5',
#  '9.3',
#  '9.2',
#  '7.6',
#  '8.7',
#  '9.1',
#  '9.2',
#  '9.6',
#  '9.2',
#  '9.2',
#  '8.9',
#  '9.6',
#  '7.7',
#  '9.3',
#  '9.4',
#  '9.2',
#  '8.6',
#  '9.5',
#  '8.8',
#  '9.5',
#  '8.3',
#  '8.8',
#  '9.4',
#  '7.9',
#  '9.6',
#  '9.2',
#  '9.2',
#  '8.3',
#  '9.4',
#  '9.2',
#  '9.5',
#  '9.3',
#  ...]

# %%
df['User-Rating']=l
df
# Out:
# <ipython-input-101-38b136296adc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['User-Rating']=l
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                         Singer/Artists  \
# 0                  Kumar Sanu, Mika Singh, Neha Kakkar
# 1                             Neha Kakkar, Tony Kakkar
# 2                                        Ranveer Singh
# 3                Jyotica Tangri, Shaan, Subhro Ganguly
# 4     Asees Kaur, Rahat Fateh Ali Khan, Tanishk Bagchi
# ...                                                ...
# 2415                                            Mukesh
# 2416                                   Lata Mangeshkar
# 2417                    Lata Mangeshkar, Suresh Wadkar
# 2418                                       Jagjit Kaur
# 2419                                       Asha Bhosle
#
#                        Genre                Album/Movie User-Rating
# 0             BollywoodDance                     Simmba         8.8
# 1     BollywoodDanceRomantic                Luka Chuppi         9.0
# 2             BollywoodDance                  Gully Boy         9.7
# 3             BollywoodDance              Total Dhamaal         9.1
# 4          BollywoodRomantic                     Simmba         9.2
# ...                      ...                        ...         ...
# 2415          BollywoodDance                    Sasural         6.2
# 2416          BollywoodDance  Jab Pyar Kisi Se Hota Hai         7.2
# 2417          BollywoodDance                      Lamhe         7.5
# 2418          BollywoodDance          Shola Aur Shabnam         6.5
# 2419          BollywoodDance          Shola Aur Shabnam         6.6
#
# [2391 rows x 5 columns]

# %%
df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
df
# Out:
# <ipython-input-102-371c8b49fd25>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Album/Movie']=df['Album/Movie'].str.replace(' ','')
# <ipython-input-102-371c8b49fd25>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(' ','')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu,MikaSingh,NehaKakkar          BollywoodDance
# 1                         NehaKakkar,TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri,Shaan,SubhroGanguly          BollywoodDance
# 4     AseesKaur,RahatFatehAliKhan,TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar,SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba         8.8
# 1               LukaChuppi         9.0
# 2                 GullyBoy         9.7
# 3             TotalDhamaal         9.1
# 4                   Simmba         9.2
# ...                    ...         ...
# 2415               Sasural         6.2
# 2416  JabPyarKisiSeHotaHai         7.2
# 2417                 Lamhe         7.5
# 2418       SholaAurShabnam         6.5
# 2419       SholaAurShabnam         6.6
#
# [2391 rows x 5 columns]

# %%
df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
df
# Out:
# <ipython-input-103-7733f995defa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Singer/Artists']=df['Singer/Artists'].str.replace(',',' ')
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                  Singer/Artists                   Genre  \
# 0                KumarSanu MikaSingh NehaKakkar          BollywoodDance
# 1                         NehaKakkar TonyKakkar  BollywoodDanceRomantic
# 2                                  RanveerSingh          BollywoodDance
# 3             JyoticaTangri Shaan SubhroGanguly          BollywoodDance
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi       BollywoodRomantic
# ...                                         ...                     ...
# 2415                                     Mukesh          BollywoodDance
# 2416                             LataMangeshkar          BollywoodDance
# 2417                LataMangeshkar SureshWadkar          BollywoodDance
# 2418                                 JagjitKaur          BollywoodDance
# 2419                                 AshaBhosle          BollywoodDance
#
#                Album/Movie User-Rating
# 0                   Simmba         8.8
# 1               LukaChuppi         9.0
# 2                 GullyBoy         9.7
# 3             TotalDhamaal         9.1
# 4                   Simmba         9.2
# ...                    ...         ...
# 2415               Sasural         6.2
# 2416  JabPyarKisiSeHotaHai         7.2
# 2417                 Lamhe         7.5
# 2418       SholaAurShabnam         6.5
# 2419       SholaAurShabnam         6.6
#
# [2391 rows x 5 columns]

# %%
df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
df['tags'][0]
# Out:
# <ipython-input-104-d88c39f053ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['tags']=df['Singer/Artists']+' '+df['Genre']+' '+df['Album/Movie']+' '+df['User-Rating']
# 'KumarSanu MikaSingh NehaKakkar BollywoodDance Simmba 8.8'

# %%
new_df=df[['Song-Name','tags']]
new_df
# Out:
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1     NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2              RanveerSingh BollywoodDance GullyBoy 9.7
# 3     JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4     AseesKaur RahatFatehAliKhan TanishkBagchi Boll...
# ...                                                 ...
# 2415                  Mukesh BollywoodDance Sasural 6.2
# 2416  LataMangeshkar BollywoodDance JabPyarKisiSeHot...
# 2417  LataMangeshkar SureshWadkar BollywoodDance Lam...
# 2418      JagjitKaur BollywoodDance SholaAurShabnam 6.5
# 2419      AshaBhosle BollywoodDance SholaAurShabnam 6.6
#
# [2391 rows x 2 columns]

# %%
new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
new_df
# Out:
# <ipython-input-106-b71b42d80788>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags']=new_df['tags'].apply(lambda x:x.lower())
#                                Song-Name  \
# 0                            Aankh Marey
# 1                              Coca Cola
# 2                       Apna Time Aayega
# 3                                 Mungda
# 4                               Tere Bin
# ...                                  ...
# 2415              Jana Tumhare Pyar Mein
# 2416             Tum Jaise Bigde Babu Se
# 2417              O Yaad Nahi Bhool Gaya
# 2418   Ladi Re Ladi Tujhse Aankh Jo Ladi
# 2419  Mummy Aur Daddy Mein Ladai Ho Gayi
#
#                                                    tags
# 0     kumarsanu mikasingh nehakakkar bollywooddance ...
# 1     nehakakkar tonykakkar bollywooddanceromantic l...
# 2              ranveersingh bollywooddance gullyboy 9.7
# 3     jyoticatangri shaan subhroganguly bollywooddan...
# 4     aseeskaur rahatfatehalikhan tanishkbagchi boll...
# ...                                                 ...
# 2415                  mukesh bollywooddance sasural 6.2
# 2416  latamangeshkar bollywooddance jabpyarkisisehot...
# 2417  latamangeshkar sureshwadkar bollywooddance lam...
# 2418      jagjitkaur bollywooddance sholaaurshabnam 6.5
# 2419      ashabhosle bollywooddance sholaaurshabnam 6.6
#
# [2391 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv=CountVectorizer(max_features=2000)

# %%
vectors=cv.fit_transform(new_df['tags']).toarray()

# %%
vectors.shape
# Out:
# (2391, 1697)

# %%
cv.get_feature_names_out
# Out:
# <bound method CountVectorizer.get_feature_names_out of CountVectorizer(max_features=2000)>

# %% [markdown]
# from sklearn.metrics.pairwise import cosine_similarity
# similarity=cosine_similarity(vectors)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

# %%
# sorted(list(enumerate(your_iterable)), reverse=True)

# %%
new_df.rename(columns={'Song-Name':'title'},inplace=True)
# Out:
# <ipython-input-113-9a52c662c89c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df.rename(columns={'Song-Name':'title'},inplace=True)

# %%
def recommend(music):
  music_index=new_df[new_df['title']==music].index[0]
  distances=similarity[music_index]
  music_list=sorted(list(enumerate(distances)),reverse=True,key=lambda x:x[1])[1:6]

  for i in music_list:
    print(new_df.iloc[i[0]].title)

# %%
recommend('Nach Meri Jaan')
# Out:
# Radio
# Sweetheart
# Gold Tamba
# O O Jaane Jaana
# Rangtaari

# %%
df.head()
# Out:
#           Song-Name                             Singer/Artists  \
# 0       Aankh Marey             KumarSanu MikaSingh NehaKakkar
# 1         Coca Cola                      NehaKakkar TonyKakkar
# 2  Apna Time Aayega                               RanveerSingh
# 3            Mungda          JyoticaTangri Shaan SubhroGanguly
# 4          Tere Bin  AseesKaur RahatFatehAliKhan TanishkBagchi
#
#                     Genre   Album/Movie User-Rating  \
# 0          BollywoodDance        Simmba         8.8
# 1  BollywoodDanceRomantic    LukaChuppi         9.0
# 2          BollywoodDance      GullyBoy         9.7
# 3          BollywoodDance  TotalDhamaal         9.1
# 4       BollywoodRomantic        Simmba         9.2
#
#                                                 tags
# 0  KumarSanu MikaSingh NehaKakkar BollywoodDance ...
# 1  NehaKakkar TonyKakkar BollywoodDanceRomantic L...
# 2           RanveerSingh BollywoodDance GullyBoy 9.7
# 3  JyoticaTangri Shaan SubhroGanguly BollywoodDan...
# 4  AseesKaur RahatFatehAliKhan TanishkBagchi Boll...

# %%
import pickle
pickle.dump(new_df,open('musicrec.pkl','wb'))

# %%
pickle.dump(new_df,open('similarities.pkl','wb'))
